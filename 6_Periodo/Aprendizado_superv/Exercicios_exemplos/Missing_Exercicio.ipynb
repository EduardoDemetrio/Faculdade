# %% [markdown]
# <h1><center>Identificação dos tipos de valores ausentes </center></h1>
# <center> Eduardo Vargas Ferreira

# %% [markdown]
# Você recebeu três conjuntos de dados anônimos (`Base_A`, `Base_B`, `Base_C`), todos derivados da mesma base original, mas com valores ausentes inseridos artificialmente na variável `glicose`. Sua tarefa é investigar os dados e responder:

# %% [markdown]
# 1. Qual das bases possui valores ausentes de forma totalmente aleatória (MCAR)?
# 2. Em qual base os valores ausentes parecem estar relacionados a variáveis observáveis como idade ou sexo (MAR)?
# 3. Qual base apresenta um padrão onde os dados ausentes estão entre os valores extremos da própria variável glicose (MNAR)?

# %% [markdown]
# ### Dicas para sua análise:
# - Verifique a distribuição de glicose (com e sem os valores ausentes);
# - Explore a relação entre ausência e variáveis como idade e sexo;
# - Use gráficos, tabelas e agrupamentos para te ajudar a investigar.
